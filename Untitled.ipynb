# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
from word2number import w2n

from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.area, df.price,color="red",marker="d")
plt.plot(df.area,reg.predict(df[["area"]]))
plt.xlabel("area")
plt.ylabel("prices");

# %%
reg = LinearRegression()
reg.fit(df[["area"]], df["price"])
# Out:
# LinearRegression()

# %%
reg.predict([[5000]])
# Out:
# c:\Users\Selltricks\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
d = pd.read_csv('areas.csv')
d.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
p=reg.predict(d)

# %%
d["prices"] = p

# %%
d.head()
# Out:
#    area         prices
# 0  1000  316404.109589
# 1  1500  384297.945205
# 2  2300  492928.082192
# 3  3540  661304.794521
# 4  4120  740061.643836

# %% [markdown]
# # exercise

# %%
df1 = pd.read_csv("canada_per_capita_income.csv")
df1.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
pred = LinearRegression()

# %%
pred.fit(df1[["year"]],df1["per capita income (US$)"])
# Out:
# LinearRegression()

# %%
pred.predict([[2020]])
# Out:
# c:\Users\Selltricks\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %% [markdown]
# # multivariate regression

# %%
df2 = pd.read_csv("homeprice.csv")
df2
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df2["bedrooms"] = df2["bedrooms"].fillna(df2["bedrooms"].median())
df2
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
reg1 = LinearRegression()
reg1.fit(df2[["area","bedrooms","age"]],df2.price)
# Out:
# LinearRegression()

# %%
reg1.predict([[2500,4,5]])
# Out:
# c:\Users\Selltricks\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([578876.03748933])

# %%
# !pip install word2number as w2n
df3 = pd.read_csv("hiring.csv")
df3
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df3["experience"] = df3["experience"].fillna("zero")

# %%
df3
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
# df3['experience'] = df3['experience'].apply(lambda x: w2n.word_to_num(x))
# df3 = df3.rename(columns={"salary($)": "salary"})
# df3["test_score(out of 10)"] = df3["test_score(out of 10)"].fillna(df3["test_score(out of 10)"].mean())
df3
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary
# 0           0               8.000000                           9   50000
# 1           0               8.000000                           6   45000
# 2           5               6.000000                           7   60000
# 3           2              10.000000                          10   65000
# 4           7               9.000000                           6   70000
# 5           3               7.000000                          10   62000
# 6          10               7.857143                           7   72000
# 7          11               7.000000                           8   80000

# %%
reg3 = LinearRegression()
reg3.fit(df3[["experience","test_score(out of 10)","interview_score(out of 10)"]],df3.salary)
# Out:
# LinearRegression()

# %%
print("Predicted Salary:", reg3.predict([[4, 6.4, 8]])[0])
# Out:
# Predicted Salary: 58366.4723945561
# c:\Users\Selltricks\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pickle
with open("salary_model.pkl", "wb") as file:
    pickle.dump(reg3, file)
print("Model Saved Successfully!")
# Out:
# Model Saved Successfully!
